# %%
## Building a bijective map relation: a bijective map builds a correspondance
## map from one domain (numbers) to another (letters).

bijective_map = {
    1: 'a',
    2: 'b',
    3: 'c',
    1: 'c',
    2: 'a'
}

print(bijective_map)
# Out:
# {1: 'c', 2: 'a', 3: 'c'}

# %%
## Working with a heap using an ordered list. Heaps allow you to find the
## largest and smallest elements in the list, in addition to writing to the
## list (push) and removing from the list (pop).

import heapq

## Creating an initial heap
h = [10, 20, 15, 30, 40]
heapq.heapify(h)

print(h)

## Appending an element to list.
heapq.heappush(h, 5)

## Append another element, remove the smallest element.
heapq.heappush(h, 7)
print("push", h)
heapq.heappop(h)
print("pop", h)

## return three smallest values from heap.
min = heapq.nsmallest(3, h)
print("3 smallest elements:", min)

## return four largest values from heap.
maxi = heapq.nlargest(2, h)
print("2 largest elements:", maxi)
# Out:
# [10, 20, 15, 30, 40]
# push [5, 20, 7, 30, 40, 15, 10]
# pop [7, 20, 10, 30, 40, 15]
# 3 smallest elements: [7, 10, 15]
# 2 largest elements: [40, 30]

# %%
import struct

## Pack values {1,2} into binary format. 'hh' is a format string that returns
## two bytes for each integer.
var = struct.pack('hh', 1, 2)
print(var)

## Unpack binary values corresponding to {1,2} --> 'hh' in a 2-tuple.
tup = struct.unpack('hh', var)
print(tup)
# Out:
# b'\x01\x00\x02\x00'
# (1, 2)

# %%
## Create a class called "dog" that allows you to specify any possible dog
## you encounter. Objects are instances of the dog class where the attributes
## are stored. Class should be expressive: attributes and instances should
## allow you to spcify the class.

class Dog:
    breed1 = "Pit Bull Mix"  ## Class attributes
    breed2 = "German Sheppard"
    breed3 = "Beagle"

    def __init__(self, name, age):
        self.name = name  ## Instance attributes
        self.age = age

## Creating objects of the Dog class
dog1 = Dog("Kious", 10)
dog2 = Dog("Della", 6)
dog3 = Dog("Buddy", 4)

print(dog1.name)
print(dog1.age)
print(dog1.breed1)
print(dog2.name)
print(dog2.age)
print(dog2.breed2)
print(dog3.name)
print(dog3.age)
print(dog3.breed3)
# Out:
# Kious
# 10
# Pit Bull Mix
# Della
# 6
# German Sheppard
# Buddy
# 4
# Beagle

# %%
## Defining class MyClass without instantiation (no instances nor attributes)
class MyClass(object):
    def MyMethod(self):
        print(self)

MyObject = MyClass()
print(MyObject)

# %%
## Stack: operates on the LIFO principle (Last In, First Out).

stack = []
stack.append(1)  ## Push: {1,2,3,4}
stack.append(2)
stack.append(3)
stack.append(4)
stack.append(5)
stack.pop()  ## Pop: {4}
print(stack)  ## Output: {1,2,3}
# Out:
# [1, 2, 3, 4]

# %%
import networkx as nx
import matplotlib.pyplot as plt

## Create a directed graph
graph = nx.DiGraph()

## Add nodes
graph.add_nodes_from([1, 2, 3, 4, 5])

## Add edges with weights
graph.add_edge(1, 2, weight=1)
graph.add_edge(2, 3, weight=0.5)
graph.add_edge(3, 4, weight=0.2)
graph.add_edge(2, 4, weight=0.2)
graph.add_edge(1, 3, weight=1)
graph.add_edge(1, 4, weight=0.5)
graph.add_edge(3, 5, weight=0.8)


## Access nodes and edges
print("Nodes:", graph.nodes)
print("Edges:", graph.edges(data=True))

## Visualize the graph (using matplotlib)
nx.draw(graph, with_labels=True)
plt.show()
# Out:
# Nodes: [1, 2, 3, 4, 5]
# Edges: [(1, 2, {'weight': 1}), (1, 3, {'weight': 1}), (1, 4, {'weight': 0.5}), (2, 3, {'weight': 0.5}), (2, 4, {'weight': 0.2}), (3, 4, {'weight': 0.2}), (3, 5, {'weight': 0.8})]

# %%
## pandas.DataFrame(data, index, columns)
## source data.
## index = defining rows (cases).
## columns = variable names.
import pandas as pd
data = [10,20,30,40,50,60]
df = pd.DataFrame(data, columns=['Numbers'])
## Display df in a stylized manner.
df
# Out:
#    Numbers
# 0       10
# 1       20
# 2       30
# 3       40
# 4       50
# 5       60

# %%
## Python code demonstrate creating
## pandas DataFrame with indexed by

## DataFrame using arrays.
import pandas as pd

## Initialize data of lists.
data = {'Name': ['Tom', 'Jack', 'nick', 'juli'],
        'marks': [99, 98, 95, 90]}

## Creates pandas DataFrame.
df = pd.DataFrame(data, index=['rank1',
                               'rank2',
                               'rank3',
                               'rank4'])
## Display df in a stylized manner.
df
# Out:
#        Name  marks
# rank1   Tom     99
# rank2  Jack     98
# rank3  nick     95
# rank4  juli     90

# %%
## Create a Pandas DataFrame with lists of dictionaries + row and column indexes.
import pandas as pd

## Initialize lists data.
data = [{'a': 1, 'b': 2},
        {'a': 5, 'b': 10, 'c': 20}]

## With two column indices, values same
## as dictionary keys
df1 = pd.DataFrame(data, index=['first',
                                'second'],
                   columns=['a', 'b'])

# With two column indices with
# one index with other name
df2 = pd.DataFrame(data, index=['first',
                                'second'],
                   columns=['a', 'b1'])

## print for first data frame
print(df1, "\n")

## Print for second DataFrame.
print(df2)
# Out:
#         a   b
# first   1   2
# second  5  10
#
#         a  b1
# first   1 NaN
# second  5 NaN

# %%
## Python code demonstrate creating
## Pandas Dataframe from Dicts of series.

import pandas as pd

# Initialize data to Dicts of series.
d = {'one': pd.Series([10, 20, 30, 40],
                      index=['a', 'b', 'c', 'd']),
     'two': pd.Series([10, 20, 30, 40],
                      index=['a', 'b', 'c', 'd'])}

## creates Dataframe.
df = pd.DataFrame(d)

## print the data.
df
# Out:
#    one  two
# a   10   10
# b   20   20
# c   30   30
# d   40   40
